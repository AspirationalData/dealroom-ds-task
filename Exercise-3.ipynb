# %% [markdown]
# ### The goal of this exercise is finding duplicates in this file.
# ### However, what we consider "duplicate" might vary from person to person, so in this exercise we'll generate different files for each approach we use to find duplicates.
#
# ### For example, we might consider one datapoint as duplicate if various relevant columns (features) of the dataframe have the same values.
# ### For example, we could abide by the rule: if "name" and "id" coincide, then it's a duplicate.

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/local/Documents/dealroom-ds-task/data/data_scientist_duplicate_detection.csv')
df
# Out:
#             id                             name  \
# 0      1501006                     QA Education
# 1      1370997              Seeking Millionaire
# 2      1726114                          LullaMe
# 3      1475926                         Book Box
# 4       223088                   Uncharted Play
# ...        ...                              ...
# 15891   868858  Cunesoft, a Phlexglobal company
# 15892  1464030       User Interface Design Gmbh
# 15893     6564                        ConWeaver
# 15894   147345                       StackShare
# 15895   970275                 HUGIN EXPERT A/S
#
#                                                  tagline             industry  \
# 0      QA Education Magazine, guide to purchasing ser...                 Kids
# 1      Millionaire dating website that matches those ...               Dating
# 2      Manufacturer of self-rocking baby mattress for...                 Kids
# 3                                               Book Box                 Kids
# 4                                                    NaN                 Kids
# ...                                                  ...                  ...
# 15891  Cloud-based regulatory software solutions and ...  Enterprise Software
# 15892  UX Design & UI Development | UID User Interfac...  Enterprise Software
# 15893  Softwares for the automatic integration of cor...  Enterprise Software
# 15894                           Developer Social Network  Enterprise Software
# 15895                        Hugin Expert | Hugin Expert  Enterprise Software
#
#             industry_2  type                                         address  \
# 0                  NaN     2                         United Kingdom, Chorley
# 1                  NaN     2                        United States, Las Vegas
# 2               Health     2     Kuortanegatan 2, 00510 Helsingfors, Finland
# 3      Wellness Beauty     2                             02000 Kiev, Ukraine
# 4                  NaN     2                         United States, New York
# ...                ...   ...                                             ...
# 15891           Health     2  Luise-Ullrich-Straße 20, 80636 Munich, Germany
# 15892              NaN     2                            Germany, Ludwigsburg
# 15893              NaN     2        Friedenspl. 12, 64283 Darmstadt, Germany
# 15894            Media     2                    United States, Mountain View
# 15895              NaN     4                Denmark, Aalborg, Gasværksvej, 5
#
#                      street street_number    zip         country  \
# 0                       NaN           NaN  PR7 2  United Kingdom
# 1                       NaN           NaN    NaN   United States
# 2             Kuortanegatan             2  00510         Finland
# 3                       NaN           NaN  02000         Ukraine
# 4                       NaN           NaN  10007   United States
# ...                     ...           ...    ...             ...
# 15891  Luise-Ullrich-Straße            20    NaN         Germany
# 15892                   NaN           NaN  71638         Germany
# 15893         Friedensplatz           NaN    NaN         Germany
# 15894                   NaN           NaN    NaN   United States
# 15895           Gasværksvej             5   9000         Denmark
#
#                 city                                            sectors
# 0            Chorley                                                NaN
# 1          Las Vegas                                                NaN
# 2        Helsingfors  femtech,automated process,outside tech,Automat...
# 3               Kiev                                    Human Resources
# 4           New York                                                NaN
# ...              ...                                                ...
# 15891         Munich  back office,moving services,Data Analytics,dat...
# 15892    Ludwigsburg                                   Innovation Radar
# 15893      Darmstadt  industrial analytics,industrial technology,Avi...
# 15894  Mountain View  Open Source,chat,social network,Infrastructure...
# 15895        Aalborg                                           computer
#
# [15896 rows x 13 columns]

# %%
dups_id_name_overlap = df.loc[df.duplicated(subset=['id', 'name']), :]

# Export duplicates to file.
dups_id_name_overlap.to_csv("~/Documents/dealroom-ds-task/output_csv/dups_id_name_overlap.csv")

# %%
dups_tagline_name_overlap = df.loc[df.duplicated(subset=['tagline', 'name']), :]

# Export duplicates to file.
dups_tagline_name_overlap.to_csv("~/Documents/dealroom-ds-task/output_csv/dups_tagline_name_overlap.csv")

# %%
# Duplicate = Coincidence in "zip" and "name".
dups_zip_name_overlap = df.loc[df.duplicated(subset=['zip', 'name']), :]

# Export duplicates to file.
dups_zip_name_overlap.to_csv("~/Documents/dealroom-ds-task/output_csv/dups_zip_name_overlap.csv")

# %%
# Duplicate = Coincidence in "address" and "name".
dups_adress_name_overlap = df.loc[df.duplicated(subset=['address', 'name']), :]

# Export duplicates to file.
dups_adress_name_overlap.to_csv("~/Documents/dealroom-ds-task/output_csv/dups_adress_name_overlap.csv")
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### We considered different options to check for duplicates and we dumped the duplicate datapoints to different files in order to decide later which datapoints to drop, depending on which criteria we find the most fitting.

# %% [markdown]
# ### Now, we'll explore some more "manual" ways to find the number of duplicates in total in the dataset.

# %%
# Alternate way to check if there's any duplicate (we check all the elements of the row, row by row).

temp_var = df.duplicated()
dup_num = 0

for dup in temp_var:
    if dup == True:
        dup_num += 1
    
print(dup_num)

type(temp_var)
# Out:
# 1
# pandas.core.series.Series

# %%
# Alternate Approach for checking total row duplicates. (Exact coincidence, element per element in a row.)
df.duplicated().sum()
# Out:
# 1

# %%
# We'll check another column.

# %%
# We'll show on the screen the duplicated rows. It will show the UNIQUE INSTANCES that are duplicated.
# This means that even if a row is duplicated multiple times, it will only show up once in the output.
df.loc[df.duplicated(), :]
# Out:
#          id             name                     tagline industry industry_2  \
# 655  867000  Swarovski Group  Homepage - Swarovski Group      NaN        NaN
#
#      type                                        address            street  \
# 655     4  Switzerland, Männedorf, Alte Landstrasse, 411  Alte Landstrasse
#
#     street_number   zip      country       city sectors
# 655           411  8708  Switzerland  Männedorf     NaN

# %%
# We create the "duplicates variable" from the command we ran above.
duplicates = df.loc[df.duplicated(), :]

# We dump our duplicates to a file.
duplicates.to_csv("~/Documents/dealroom-ds-task/output_csv/duplicates.csv")

# %%
df.loc[df.tagline.duplicated(), :]
# Out:
#             id                                               name  \
# 25     2851294                                   BotBuilders.Tech
# 50      130636                                            iCreate
# 65     1314213  The Johns Hopkins Bloomberg School of Public H...
# 69     2026805                 Electus Global Education Co., Inc.
# 72     2944774                                             Photon
# ...        ...                                                ...
# 15789   180438                                           3Seventy
# 15814  2941985                                         Paperspace
# 15837   134996                                      PerfectSearch
# 15856   151814                                    Solstice Mobile
# 15865  2320171                                       Marumatchbox
#
#                                                  tagline             industry  \
# 25                                                   NaN                 Kids
# 50                                                   NaN                 Kids
# 65     Research, education, and practice to find solu...                 Kids
# 69                                                   NaN                 Kids
# 72                                                   NaN                 Kids
# ...                                                  ...                  ...
# 15789                                                NaN  Enterprise Software
# 15814                                                NaN  Enterprise Software
# 15837                                                NaN  Enterprise Software
# 15856                                                NaN  Enterprise Software
# 15865                                                NaN  Enterprise Software
#
#       industry_2  type                             address street  \
# 25           NaN     2  Bengaluru, Karnataka 560060, India    NaN
# 50           NaN     2               United States, Austin    NaN
# 65     Education     8            United States, Baltimore    NaN
# 69           NaN     2            Tampa, FL, United States    NaN
# 72     Education     2   Bialystok, Woj. Podlaskie, Poland    NaN
# ...          ...   ...                                 ...    ...
# 15789        NaN     2               United States, Austin    NaN
# 15814        NaN     2         Brooklyn, NY, United States    NaN
# 15837        NaN     2                 United States, Orem    NaN
# 15856        NaN     2              United States, Chicago    NaN
# 15865        NaN     2                 Toronto, ON, Canada    NaN
#
#       street_number     zip        country       city sectors
# 25              NaN  560060          India  Bengaluru     NaN
# 50              NaN     NaN  United States     Austin     NaN
# 65              NaN     NaN  United States  Baltimore     NaN
# 69              NaN   33602  United States      Tampa     NaN
# 72              NaN  15-007         Poland  Bialystok     NaN
# ...             ...     ...            ...        ...     ...
# 15789           NaN     NaN  United States     Austin     NaN
# 15814           NaN   11201  United States   Brooklyn     NaN
# 15837           NaN     NaN  United States       Orem     NaN
# 15856           NaN     NaN  United States    Chicago     NaN
# 15865           NaN     M5H         Canada    Toronto     NaN
#
# [1342 rows x 13 columns]

# %%
# We take a different approach to find duplicates.
# Here we can see what "company names" are duplicated.
df.dropna().loc[df.name.duplicated(), :]
# Out:
#             id                      name  \
# 4807    123520              Planetarians
# 6498   1470717                       ASG
# 6535    863052       Breeze Technologies
# 7668    892048                     Pixyl
# 8623   1449811                  MeetinVR
# 9556    874024  Payments & Cards Network
# 9613     16240                   Quadrem
# 11522  1452118                 WritePath
# 11853   980602                   Flowtap
# 13068   867177                   Softeam
# 13892   900296          Elitac Wearables
# 14261  1476244                       TVC
# 14502  1249627                 NeuroFlow
# 14552  1256571                    Youper
# 15027    26293                    Tamoco
# 15187   122440                     Skore
# 15251   956596          Hedera Hashgraph
# 15405   109783                   Trifork
# 15516     2930                     Reply
# 15687   129779                     Wayin
#
#                                                  tagline             industry  \
# 4807   Alternative protein from upcycled seeds at the...                 Food
# 6498   Designs and manufactures resistive and superco...               Energy
# 6535   Breeze pushes the limits of environmental sens...               Energy
# 7668   Working to improve patient care by placing the...               Health
# 8623   Combines the flexibility of online meetings wi...              Fashion
# 9556   Payments & Cards Network - Jobs in Payments, F...              Fintech
# 9613                Purchase-to-pay marketplace provider              Fintech
# 11522  AI translation solution for User manual, Inves...            Education
# 11853  Flowtap is your partner for artificial intelli...            Marketing
# 13068       Consulting and technology services in France          Home Living
# 13892  Wearables developers | Experts on the integrat...       Semiconductors
# 14261  Provides complete turnkey services for OB Vans...       Transportation
# 14502  Digital health solution that analyzes real-tim...      Wellness Beauty
# 14552  An AI Therapy platform that supports mental he...      Wellness Beauty
# 15027  Provides analytics and mobile proximity techno...  Enterprise Software
# 15187          Platform for corporate education programs  Enterprise Software
# 15251  A superior consensus data structure alternativ...  Enterprise Software
# 15405  Software innovation company with the main focu...  Enterprise Software
# 15516  Defining and developing business models to opt...  Enterprise Software
# 15687       Social media intelligence and visualisations  Enterprise Software
#
#                 industry_2  type  \
# 4807       Wellness Beauty     2
# 6498        Semiconductors     4
# 6535           Real Estate     2
# 7668   Enterprise Software     2
# 8623               Telecom     2
# 9556      Jobs Recruitment     2
# 9613   Enterprise Software     2
# 11522              Fintech     2
# 11853  Enterprise Software     2
# 13068                Media    15
# 13892              Fashion     2
# 14261              Telecom     4
# 14502               Health     2
# 14552               Health     2
# 15027              Telecom     2
# 15187            Education     2
# 15251              Telecom     2
# 15405             Robotics     4
# 15516                Media    15
# 15687                Media     4
#
#                                                  address  \
# 4807            630 Hansen Way, Palo Alto, CA 94304, USA
# 6498   Corso Ferdinando Maria Perrone, 73, 16152 Geno...
# 6535   Harburger Schloßstraße 6-12, 21079 Hamburg, Ge...
# 7668   5 Avenue du Grand Sablon, 38700 La Tronche, Fr...
# 8623            6, Annexstræde, 2500 Copenhagen, Denmark
# 9556            Netherlands, Amsterdam, Herengracht, 576
# 9613                Netherlands, Amsterdam, Kabelweg, 61
# 11522  Taiwan, Taipei City, Lane 559, Sec 4, Zhong Xi...
# 11853             33, Schottenring, 1010 Vienna, Austria
# 13068       France, Paris, Avenue des Champs-Élysées, 70
# 13892   Nijverheidsweg 16b, 3534 AM Utrecht, Netherlands
# 14261            Dvaro g. 140, Šiauliai 76199, Lithuania
# 14502        1635 Market St, Philadelphia, PA 19103, USA
# 14552    315 Montgomery St, San Francisco, CA 94104, USA
# 15027          United Kingdom, London, Goodge Street, 41
# 15187  Campus São Paulo - A Google Space - Rua Corone...
# 15251     3400 N Central Expy, Richardson, TX 75082, USA
# 15405      Neuhofstrasse 8, 8834 Feusisberg, Switzerland
# 15516         Corso Francia, 110, 10143 Torino TO, Italy
# 15687          United States, Denver, Blake Street, 1623
#
#                                    street street_number        zip  \
# 4807                           Hansen Way           630      94304
# 6498       Corso Ferdinando Maria Perrone            73      16152
# 6535               Harburger Schloßstraße          6-12      21079
# 7668               Avenue du Grand Sablon             5      38700
# 8623                          Annexstræde             6       2500
# 9556                          Herengracht           576    1017 CJ
# 9613                             Kabelweg            61    1014 BA
# 11522  Lane 559, Sec 4, Zhong Xiao E. Rd.             1        110
# 11853                        Schottenring            33       1010
# 13068           Avenue des Champs-Élysées            70      75008
# 13892                      Nijverheidsweg           16b    3534 AM
# 14261                         Dvaro gatvė           140      76199
# 14502                       Market Street          1635      19103
# 14552                   Montgomery Street           315      94104
# 15027                       Goodge Street            41    W1T 2PY
# 15187             Rua Coronel Oscar Porto            70  01313-902
# 15251            North Central Expressway          3400      75082
# 15405                       Neuhofstrasse             8       8834
# 15516                       Corso Francia           110      10143
# 15687                        Blake Street          1623      80202
#
#               country           city  \
# 4807    United States      Palo Alto
# 6498            Italy         Genova
# 6535          Germany        Hamburg
# 7668           France     La Tronche
# 8623          Denmark     Copenhagen
# 9556      Netherlands      Amsterdam
# 9613      Netherlands      Amsterdam
# 11522          Taiwan    Taipei City
# 11853         Austria         Vienna
# 13068          France          Paris
# 13892     Netherlands        Utrecht
# 14261       Lithuania       Šiauliai
# 14502   United States   Philadelphia
# 14552   United States  San Francisco
# 15027  United Kingdom         London
# 15187          Brazil      São Paulo
# 15251   United States     Richardson
# 15405     Switzerland     Feusisberg
# 15516           Italy         Torino
# 15687   United States         Denver
#
#                                                  sectors
# 4807   grains,superfood,Nutrition Solution,Innovative...
# 6498   component,Medical,electromagnetic,Medical Tech...
# 6535   sustainable development goals,urban tech,Susta...
# 7668   healthcare,neurology,patient care,stroke,Biote...
# 8623                                platform,SaaS,Social
# 9556   financial service,credit card,network,Recruitm...
# 9613   Accounting,Procurement,StartupAmsterdam2020,St...
# 11522                                        translation
# 11853                                 CRM,Analytics,SaaS
# 13068  appliances,outside tech,agency,consulting serv...
# 13892  research and development,textile,Wearable,safe...
# 14261  Telecommunications,StartupLithuania,Broadcast,...
# 14502  wellness,digital health,sustainable developmen...
# 14552  sustainable development goals,mental health,He...
# 15027  Business Intelligence,Telecommunications,inter...
# 15187  Knowledge Management,Corporate Training,team c...
# 15251  cryptocurrencies,decentralised applications,Se...
# 15405  producer,Industrial Automation,industry 4.0,In...
# 15516  automated process,Aviation & Aerospace,Cloud C...
# 15687  streaming,Data Analytics,app,platform,branding...

# %%
# We can thing of this as a table in a Relational Database: same ID means it's the same element, thus duplicate.

# In order to find duplicates, we count the instances of each row.
# For that purpuse, we use Counter from collections.
from collections import Counter

id_counts = Counter(df['id'])

# or key, value in id_counts.items():
#    print(key)


# We loop through every key-value pair in the Counter dictonary. If the count is greater than one, print the ID (has duplicates)
for key, value in id_counts.items():
    if value > 1:
        # print(key)
        # print(value)
        print("({}, {})".format(key, value), end= "\n" * 2)
        print("The key (or ID) {} has a total of {} instances in this CSV file".format(key, value))


# Thenm we'll check how many duplicates the key has by calling the key.
# id_counts['867000']
# Out:
# (867000, 2)
#
# The key (or ID) 867000 has 2 instances in this CSV file

# %% [markdown]
# As you can see, there's only one row that is duplicated.
# It has two ocurrences in total in the .csv file.

# %%
for value in id_counts.values():
    if value > 1:
        print(value)
# Out:
# 2

# %%
id_counts['867000']
# Out:
# 0

# %%
# id_counts
