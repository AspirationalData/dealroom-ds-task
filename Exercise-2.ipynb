# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("~/Documents/dealroom-ds-task/data/data_scientist_intern_revenue_model.csv")
df
# Out:
#        NAME    Revenue_2015    Revenue_2016    Revenue_2017    Revenue_2018  \
# 0      LAKI  19,039,781,738  24,671,631,399  24,573,762,847  22,608,855,366
# 1      YETS   3,687,564,000   3,663,588,000   3,420,430,000   3,265,963,000
# 2      PNMD   3,139,300,000   3,214,000,000   3,196,900,000   3,193,700,000
# 3      VKNF   1,994,112,000   2,023,348,000   1,982,028,000   2,007,387,000
# 4      HHVD     761,248,939   1,121,284,088   1,245,810,056   1,317,864,838
# ...     ...             ...             ...             ...             ...
# 17419  ECYY            -               -               -               -
# 17420  GCGH            -               -               -               -
# 17421  HCRP          77,931          59,686          28,309           1,306
# 17422  JXDE          30,689           6,182           1,429             NaN
# 17423  UKZV         395,996         301,991         401,021             NaN
#
#          Revenue_2019  Employees_2017  Employees_2018  Employees_2019  \
# 0      26,574,540,757             NaN           805.0           790.0
# 1       3,465,058,000             NaN          2394.0          2494.0
# 2       3,166,000,000          6411.0          6506.0          7750.0
# 3       2,009,031,000             NaN          1925.0          1995.0
# 4       1,779,401,992             NaN          5159.0          5599.0
# ...               ...             ...             ...             ...
# 17419             NaN             NaN             NaN           100.0
# 17420            -                NaN           171.0           175.0
# 17421             NaN             NaN             NaN             NaN
# 17422             NaN             NaN             NaN             NaN
# 17423             NaN             NaN             NaN             6.0
#
#        Employees_2020  Revenue_2020(To predict)
# 0               785.0                       NaN
# 1              2548.0                       NaN
# 2                 NaN                       NaN
# 3              2050.0                       NaN
# 4              5483.0                       NaN
# ...               ...                       ...
# 17419            99.0                       NaN
# 17420           165.0                       NaN
# 17421            12.0                       NaN
# 17422             7.0                       NaN
# 17423             NaN                       NaN
#
# [17424 rows x 11 columns]

# %%
for value in df[list(df.columns)]:
    df[str(value)] = df[str(value)].replace(",", "")

df
# Out:
#        NAME    Revenue_2015    Revenue_2016    Revenue_2017    Revenue_2018  \
# 0      LAKI  19,039,781,738  24,671,631,399  24,573,762,847  22,608,855,366
# 1      YETS   3,687,564,000   3,663,588,000   3,420,430,000   3,265,963,000
# 2      PNMD   3,139,300,000   3,214,000,000   3,196,900,000   3,193,700,000
# 3      VKNF   1,994,112,000   2,023,348,000   1,982,028,000   2,007,387,000
# 4      HHVD     761,248,939   1,121,284,088   1,245,810,056   1,317,864,838
# ...     ...             ...             ...             ...             ...
# 17419  ECYY            -               -               -               -
# 17420  GCGH            -               -               -               -
# 17421  HCRP          77,931          59,686          28,309           1,306
# 17422  JXDE          30,689           6,182           1,429             NaN
# 17423  UKZV         395,996         301,991         401,021             NaN
#
#          Revenue_2019  Employees_2017  Employees_2018  Employees_2019  \
# 0      26,574,540,757             NaN           805.0           790.0
# 1       3,465,058,000             NaN          2394.0          2494.0
# 2       3,166,000,000          6411.0          6506.0          7750.0
# 3       2,009,031,000             NaN          1925.0          1995.0
# 4       1,779,401,992             NaN          5159.0          5599.0
# ...               ...             ...             ...             ...
# 17419             NaN             NaN             NaN           100.0
# 17420            -                NaN           171.0           175.0
# 17421             NaN             NaN             NaN             NaN
# 17422             NaN             NaN             NaN             NaN
# 17423             NaN             NaN             NaN             6.0
#
#        Employees_2020  Revenue_2020(To predict)
# 0               785.0                       NaN
# 1              2548.0                       NaN
# 2                 NaN                       NaN
# 3              2050.0                       NaN
# 4              5483.0                       NaN
# ...               ...                       ...
# 17419            99.0                       NaN
# 17420           165.0                       NaN
# 17421            12.0                       NaN
# 17422             7.0                       NaN
# 17423             NaN                       NaN
#
# [17424 rows x 11 columns]

# %% [markdown]
# ### Now that we know how to format the data accordingly, let's apply this operation to all the fields in the DataFrame.

# %%
# Let's visualize the dataframe to check if the changes were applied correctly.
df
# Out:
#        NAME    Revenue_2015    Revenue_2016    Revenue_2017    Revenue_2018  \
# 0      LAKI  19,039,781,738  24,671,631,399  24,573,762,847  22,608,855,366
# 1      YETS   3,687,564,000   3,663,588,000   3,420,430,000   3,265,963,000
# 2      PNMD   3,139,300,000   3,214,000,000   3,196,900,000   3,193,700,000
# 3      VKNF   1,994,112,000   2,023,348,000   1,982,028,000   2,007,387,000
# 4      HHVD     761,248,939   1,121,284,088   1,245,810,056   1,317,864,838
# ...     ...             ...             ...             ...             ...
# 17419  ECYY            -               -               -               -
# 17420  GCGH            -               -               -               -
# 17421  HCRP          77,931          59,686          28,309           1,306
# 17422  JXDE          30,689           6,182           1,429             NaN
# 17423  UKZV         395,996         301,991         401,021             NaN
#
#          Revenue_2019  Employees_2017  Employees_2018  Employees_2019  \
# 0      26,574,540,757             NaN           805.0           790.0
# 1       3,465,058,000             NaN          2394.0          2494.0
# 2       3,166,000,000          6411.0          6506.0          7750.0
# 3       2,009,031,000             NaN          1925.0          1995.0
# 4       1,779,401,992             NaN          5159.0          5599.0
# ...               ...             ...             ...             ...
# 17419             NaN             NaN             NaN           100.0
# 17420            -                NaN           171.0           175.0
# 17421             NaN             NaN             NaN             NaN
# 17422             NaN             NaN             NaN             NaN
# 17423             NaN             NaN             NaN             6.0
#
#        Employees_2020  Revenue_2020(To predict)
# 0               785.0                       NaN
# 1              2548.0                       NaN
# 2                 NaN                       NaN
# 3              2050.0                       NaN
# 4              5483.0                       NaN
# ...               ...                       ...
# 17419            99.0                       NaN
# 17420           165.0                       NaN
# 17421            12.0                       NaN
# 17422             7.0                       NaN
# 17423             NaN                       NaN
#
# [17424 rows x 11 columns]

# %%
df.columns[1 : 6]
# Out:
# Index(['Revenue_2015', 'Revenue_2016', 'Revenue_2017', 'Revenue_2018',
#        'Revenue_2019'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['NAME', 'Revenue_2015', 'Revenue_2016', 'Revenue_2017', 'Revenue_2018',
#        'Revenue_2019', 'Employees_2017', 'Employees_2018', 'Employees_2019',
#        'Employees_2020', 'Revenue_2020(To predict)'],
#       dtype='object')

# %%
df
# Out:
#        NAME    Revenue_2015    Revenue_2016    Revenue_2017    Revenue_2018  \
# 0      LAKI  19,039,781,738  24,671,631,399  24,573,762,847  22,608,855,366
# 1      YETS   3,687,564,000   3,663,588,000   3,420,430,000   3,265,963,000
# 2      PNMD   3,139,300,000   3,214,000,000   3,196,900,000   3,193,700,000
# 3      VKNF   1,994,112,000   2,023,348,000   1,982,028,000   2,007,387,000
# 4      HHVD     761,248,939   1,121,284,088   1,245,810,056   1,317,864,838
# ...     ...             ...             ...             ...             ...
# 17419  ECYY            -               -               -               -
# 17420  GCGH            -               -               -               -
# 17421  HCRP          77,931          59,686          28,309           1,306
# 17422  JXDE          30,689           6,182           1,429             NaN
# 17423  UKZV         395,996         301,991         401,021             NaN
#
#          Revenue_2019  Employees_2017  Employees_2018  Employees_2019  \
# 0      26,574,540,757             NaN           805.0           790.0
# 1       3,465,058,000             NaN          2394.0          2494.0
# 2       3,166,000,000          6411.0          6506.0          7750.0
# 3       2,009,031,000             NaN          1925.0          1995.0
# 4       1,779,401,992             NaN          5159.0          5599.0
# ...               ...             ...             ...             ...
# 17419             NaN             NaN             NaN           100.0
# 17420            -                NaN           171.0           175.0
# 17421             NaN             NaN             NaN             NaN
# 17422             NaN             NaN             NaN             NaN
# 17423             NaN             NaN             NaN             6.0
#
#        Employees_2020  Revenue_2020(To predict)
# 0               785.0                       NaN
# 1              2548.0                       NaN
# 2                 NaN                       NaN
# 3              2050.0                       NaN
# 4              5483.0                       NaN
# ...               ...                       ...
# 17419            99.0                       NaN
# 17420           165.0                       NaN
# 17421            12.0                       NaN
# 17422             7.0                       NaN
# 17423             NaN                       NaN
#
# [17424 rows x 11 columns]

# %% [markdown]
# ## We need to remove the commas that separate the numbers, since otherwise it would give us probems down the line, because data type would be STRING intead of INT.

# %% [markdown]
# ### Let's remove the thousand separator in order to be able to work with the data using scikit-learn.

# %% [markdown]
# ### We figured out a formula to remove the commas that prevent scikit-learn from being able to work with this data.
# ### We use a regular expression: substitute all special charachters with nothing.
# ### In practice, this deletes all special characters, including commas.

# %%
# This is the programming logic to do the replacing on one column only.
df['Revenue_2015'] = df['Revenue_2015'].str.replace(r'\W',"")
# Out:
# <ipython-input-81-5fa8db4186f6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Revenue_2015'] = df['Revenue_2015'].str.replace(r'\W',"")

# %%
### After deleting the space that was present after the the column 'Revenue_2015' manually, I am able to access the data from said column.
df['Revenue_2015']
# Out:
# 0        19039781738
# 1         3687564000
# 2         3139300000
# 3         1994112000
# 4          761248939
#             ...
# 17419
# 17420
# 17421          77931
# 17422          30689
# 17423         395996
# Name: Revenue_2015, Length: 17424, dtype: object

# %%
# This is the column name list that we will work with.
print(list(df.columns))
# Out:
# ['NAME', 'Revenue_2015', 'Revenue_2016', 'Revenue_2017', 'Revenue_2018', 'Revenue_2019', 'Employees_2017', 'Employees_2018', 'Employees_2019', 'Employees_2020', 'Revenue_2020(To predict)']

# %%
# We don't need to modify every column, but the following ones:
df.columns[1 : 6]
# Out:
# Index(['Revenue_2015', 'Revenue_2016', 'Revenue_2017', 'Revenue_2018',
#        'Revenue_2019'],
#       dtype='object')

# %%
# We only include columns that have comma separators. The one that have decimal separator do not need to be converted, since they can be converted to INT automatically
#  and don't abide by the REGEX rule we created.

# We exclude the first and the last column in this loop.
for value in df.columns[1 : 6]:
    df[str(value)] = df[str(value)].str.replace(r'\W',"")
# Out:
# <ipython-input-91-7f5ea2267919>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[str(value)] = df[str(value)].str.replace(r'\W',"")

# %%
### We check if the transformation was successful by printing the modified DataFrame.
df
# Out:
#        NAME Revenue_2015 Revenue_2016 Revenue_2017 Revenue_2018 Revenue_2019  \
# 0      LAKI  19039781738  24671631399  24573762847  22608855366  26574540757
# 1      YETS   3687564000   3663588000   3420430000   3265963000   3465058000
# 2      PNMD   3139300000   3214000000   3196900000   3193700000   3166000000
# 3      VKNF   1994112000   2023348000   1982028000   2007387000   2009031000
# 4      HHVD    761248939   1121284088   1245810056   1317864838   1779401992
# ...     ...          ...          ...          ...          ...          ...
# 17419  ECYY                                                              NaN
# 17420  GCGH
# 17421  HCRP        77931        59686        28309         1306          NaN
# 17422  JXDE        30689         6182         1429          NaN          NaN
# 17423  UKZV       395996       301991       401021          NaN          NaN
#
#        Employees_2017  Employees_2018  Employees_2019  Employees_2020  \
# 0                 NaN           805.0           790.0           785.0
# 1                 NaN          2394.0          2494.0          2548.0
# 2              6411.0          6506.0          7750.0             NaN
# 3                 NaN          1925.0          1995.0          2050.0
# 4                 NaN          5159.0          5599.0          5483.0
# ...               ...             ...             ...             ...
# 17419             NaN             NaN           100.0            99.0
# 17420             NaN           171.0           175.0           165.0
# 17421             NaN             NaN             NaN            12.0
# 17422             NaN             NaN             NaN             7.0
# 17423             NaN             NaN             6.0             NaN
#
#        Revenue_2020(To predict)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 17419                       NaN
# 17420                       NaN
# 17421                       NaN
# 17422                       NaN
# 17423                       NaN
#
# [17424 rows x 11 columns]

# %%
We could use 0 instead of np.nan to transform values to INT.

# %% [markdown]
# ### We will use SimpleImputer from scikit-learn to fill out NaN values with the row's mean, so that we have all the data we need to predict the 2020's revenue using a Linear Regression.
#
# ### After calculating the linear model, we will evaluate the goodness of fit of this model.

# %%
# We convert the dataframe into an array and discard the last column, the variable to predict.
df_process = df.iloc[:, :-1].values
df_process
# Out:
# array([['LAKI', '19039781738', '24671631399', ..., 805.0, 790.0, 785.0],
#        ['YETS', '3687564000', '3663588000', ..., 2394.0, 2494.0, 2548.0],
#        ['PNMD', '3139300000', '3214000000', ..., 6506.0, 7750.0, nan],
#        ...,
#        ['HCRP', '77931', '59686', ..., nan, nan, 12.0],
#        ['JXDE', '30689', '6182', ..., nan, nan, 7.0],
#        ['UKZV', '395996', '301991', ..., nan, 6.0, nan]], dtype=object)

# %%
# We create a "mean_imputer" option with the appropiate parameters to perform the preprocessing.
mean_imputer = SimpleImputer(missing_values=[np.nan, ''], strategy="mean", verbose=0)

# %%
df_process = mean_imputer.fit_transform(df_process[1:, 1:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-1025fec66476> in <module>
# ----> 1 df_process = mean_imputer.fit_transform(df_process[1:, 1:10])
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
#     290         # default fill_value is 0 for numerical input and "missing_value"
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/sklearn/impute/_base.py in _validate_input(self, X, in_fit)
#     258                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     259                                     "data:\n{}".format(self.strategy, ve))
# --> 260                 raise new_ve from None
#     261             else:
#     262                 raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: ''

# %%
# mean_imputer = mean_imputer.fit(df_process[1:, 1:10])
# df_process = mean_imputer.transform(df_process[1:, 1:10])
# df_process
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-22c0133701aa> in <module>
# ----> 1 mean_imputer = mean_imputer.fit(df_process[1:, 1:10])
#       2 df_process = mean_imputer.transform(df_process[1:, 1:10])
#       3 df_process
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
#     290         # default fill_value is 0 for numerical input and "missing_value"
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/sklearn/impute/_base.py in _validate_input(self, X, in_fit)
#     258                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     259                                     "data:\n{}".format(self.strategy, ve))
# --> 260                 raise new_ve from None
#     261             else:
#     262                 raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: ''
